# %%
import pandas as pd
import sys
# !{sys.executable} -m pip install pyarrow
import pyarrow.parquet as pq

# %%
parquet_file = "opentarget/OT_target_2023-04-01.parquet"

# %%
pd.read_parquet(parquet_file, engine='auto')
# Out:
#                   id   approvedSymbol               biotype  \
# 0    ENSG00000020219          CCT8L1P  processed_pseudogene
# 1    ENSG00000059588           TARBP1        protein_coding
# 2    ENSG00000070182             SPTB        protein_coding
# 3    ENSG00000070366             SMG6        protein_coding
# 4    ENSG00000072071           ADGRL1        protein_coding
# ..               ...              ...                   ...
# 321  ENSG00000290546  ENSG00000290546                lncRNA
# 322  ENSG00000290612  ENSG00000290612                lncRNA
# 323  ENSG00000290667  ENSG00000290667                lncRNA
# 324  ENSG00000290676       SERPINA13P                lncRNA
# 325  ENSG00000291119        DPY19L2P4                lncRNA
#
#                                          transcriptIds  \
# 0                                    [ENST00000465400]
# 1    [ENST00000496673, ENST00000483404, ENST0000048...
# 2    [ENST00000553938, ENST00000389720, ENST0000055...
# ...
